# %%
# !pip install -U openmim

# %%
# !mim install mmengine

# %%
# !pip install mmcv==2.1.0 -f https://download.openmmlab.com/mmcv/dist/cu121/torch2.1/index.html

# %%
# !mim install mmdet

# %%
# !git clone https://github.com/open-mmlab/mmdetection.git

# %%
cd mmdetection

# %%
# !wget https://download.openmmlab.com/mmyolo/data/cat_dataset.zip

# %%
# !unzip cat_dataset.zip -d data/cat/

# %%
# !python demo/image_demo.py data/cat/images/IMG_20211205_120756.jpg configs/grounding_dino/grounding_dino_swin-t_finetune_8xb2_20e_cat.py --weights https://download.openmmlab.com/mmdetection/v3.0/grounding_dino/groundingdino_swint_ogc_mmdet-822d7e9d.pth --texts cat.

# %%
# !python tools/test.py configs/grounding_dino/grounding_dino_swin-t_finetune_8xb2_20e_cat.py https://download.openmmlab.com/mmdetection/v3.0/grounding_dino/groundingdino_swint_ogc_mmdet-822d7e9d.pth

# %%
# !python ./tools/train.py configs/grounding_dino/grounding_dino_swin-t_finetune_8xb2_20e_cat.py --work-dir defect_work_dir
# Out:
# 07/21 13:55:25 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1548781279
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu121
#     OpenCV: 4.8.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1548781279
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/21 13:55:27 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# class_name = (
#     'Defect1',
#     'Defect2',
#     'Defect3',
#     'Defect4',
#     'Defect5',
# )
# data_root = 'data/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1, max_keep_ckpts=1, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=5, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# lang_model_name = 'bert-base-uncased'
# launcher = 'none'
# load_from = 'https://download.openmmlab.com/mmdetection/v3.0/grounding_dino/groundingdino_swint_ogc_mmdet-822d7e9d.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epoch = 10
# max_epochs = 12
# metainfo = dict(
#     classes=(
#         'Defect1',
#         'Defect2',
#         'Defect3',
#         'Defect4',
#         'Defect5',
#     ),
#     palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#         (
#             119,
#             11,
#             32,
#         ),
#         (
#             0,
#             0,
#             142,
#         ),
#         (
#             0,
#             255,
#             0,
#         ),
#         (
#             255,
#             165,
#             0,
#         ),
#     ])
# model = dict(
#     as_two_stage=True,
#     backbone=dict(
#         attn_drop_rate=0.0,
#         convert_weights=False,
#         depths=[
#             2,
#             2,
#             6,
#             2,
#         ],
#         drop_path_rate=0.2,
#         drop_rate=0.0,
#         embed_dims=96,
#         mlp_ratio=4,
#         num_heads=[
#             3,
#             6,
#             12,
#             24,
#         ],
#         out_indices=(
#             1,
#             2,
#             3,
#         ),
#         patch_norm=True,
#         qk_scale=None,
#         qkv_bias=True,
#         type='SwinTransformer',
#         window_size=7,
#         with_cp=True),
#     bbox_head=dict(
#         contrastive_cfg=dict(bias=False, log_scale=0.0, max_text_len=256),
#         loss_bbox=dict(loss_weight=5.0, type='L1Loss'),
#         loss_cls=dict(
#             alpha=0.25,
#             gamma=2.0,
#             loss_weight=1.0,
#             type='FocalLoss',
#             use_sigmoid=True),
#         loss_iou=dict(loss_weight=2.0, type='GIoULoss'),
#         num_classes=5,
#         sync_cls_avg_factor=True,
#         type='GroundingDINOHead'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_mask=False,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     decoder=dict(
#         layer_cfg=dict(
#             cross_attn_cfg=dict(dropout=0.0, embed_dims=256, num_heads=8),
#             cross_attn_text_cfg=dict(dropout=0.0, embed_dims=256, num_heads=8),
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=2048, ffn_drop=0.0),
#             self_attn_cfg=dict(dropout=0.0, embed_dims=256, num_heads=8)),
#         num_layers=6,
#         post_norm_cfg=None,
#         return_intermediate=True),
#     dn_cfg=dict(
#         box_noise_scale=1.0,
#         group_cfg=dict(dynamic=True, num_dn_queries=100, num_groups=None),
#         label_noise_scale=0.5),
#     encoder=dict(
#         fusion_layer_cfg=dict(
#             embed_dim=1024,
#             init_values=0.0001,
#             l_dim=256,
#             num_heads=4,
#             v_dim=256),
#         layer_cfg=dict(
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=2048, ffn_drop=0.0),
#             self_attn_cfg=dict(dropout=0.0, embed_dims=256, num_levels=4)),
#         num_cp=6,
#         num_layers=6,
#         text_layer_cfg=dict(
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=1024, ffn_drop=0.0),
#             self_attn_cfg=dict(dropout=0.0, embed_dims=256, num_heads=4))),
#     language_model=dict(
#         add_pooling_layer=False,
#         name='bert-base-uncased',
#         pad_to_max=False,
#         special_tokens_list=[
#             '[CLS]',
#             '[SEP]',
#             '.',
#             '?',
#         ],
#         type='BertModel',
#         use_sub_sentence_represent=True),
#     neck=dict(
#         act_cfg=None,
#         bias=True,
#         in_channels=[
#             192,
#             384,
#             768,
#         ],
#         kernel_size=1,
#         norm_cfg=dict(num_groups=32, type='GN'),
#         num_outs=4,
#         out_channels=256,
#         type='ChannelMapper'),
#     num_queries=900,
#     positional_encoding=dict(
#         normalize=True, num_feats=128, offset=0.0, temperature=20),
#     test_cfg=dict(max_per_img=300),
#     train_cfg=dict(
#         assigner=dict(
#             match_costs=[
#                 dict(type='BinaryFocalLossCost', weight=2.0),
#                 dict(box_format='xywh', type='BBoxL1Cost', weight=5.0),
#                 dict(iou_mode='giou', type='IoUCost', weight=2.0),
#             ],
#             type='HungarianAssigner')),
#     type='GroundingDINO',
#     with_box_refine=True)
# num_classes = 5
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=0.1, norm_type=2),
#     optimizer=dict(lr=5e-05, type='AdamW', weight_decay=0.0001),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             absolute_pos_embed=dict(decay_mult=0.0),
#             backbone=dict(lr_mult=0.1),
#             language_model=dict(lr_mult=0))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(begin=0, by_epoch=False, end=30, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=10,
#         gamma=0.1,
#         milestones=[
#             15,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='test/'),
#         data_root='data/',
#         metainfo=dict(
#             classes=(
#                 'Defect1',
#                 'Defect2',
#                 'Defect3',
#                 'Defect4',
#                 'Defect5',
#             ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     0,
#                     0,
#                     142,
#                 ),
#                 (
#                     0,
#                     255,
#                     0,
#                 ),
#                 (
#                     255,
#                     165,
#                     0,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 800,
#                 1333,
#             ), type='FixScaleResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'text',
#                     'custom_entities',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         return_classes=True,
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/test/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         800,
#         1333,
#     ), type='FixScaleResize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'text',
#             'custom_entities',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=10, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='data/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'Defect1',
#                 'Defect2',
#                 'Defect3',
#                 'Defect4',
#                 'Defect5',
#             ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     0,
#                     0,
#                     142,
#                 ),
#                 (
#                     0,
#                     255,
#                     0,
#                 ),
#                 (
#                     255,
#                     165,
#                     0,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(
#                 transforms=[
#                     [
#                         dict(
#                             keep_ratio=True,
#                             scales=[
#                                 (
#                                     480,
#                                     1333,
#                                 ),
#                                 (
#                                     512,
#                                     1333,
#                                 ),
#                                 (
#                                     544,
#                                     1333,
#                                 ),
#                                 (
#                                     576,
#                                     1333,
#                                 ),
#                                 (
#                                     608,
#                                     1333,
#                                 ),
#                                 (
#                                     640,
#                                     1333,
#                                 ),
#                                 (
#                                     672,
#                                     1333,
#                                 ),
#                                 (
#                                     704,
#                                     1333,
#                                 ),
#                                 (
#                                     736,
#                                     1333,
#                                 ),
#                                 (
#                                     768,
#                                     1333,
#                                 ),
#                                 (
#                                     800,
#                                     1333,
#                                 ),
#                             ],
#                             type='RandomChoiceResize'),
#                     ],
#                     [
#                         dict(
#                             keep_ratio=True,
#                             scales=[
#                                 (
#                                     400,
#                                     4200,
#                                 ),
#                                 (
#                                     500,
#                                     4200,
#                                 ),
#                                 (
#                                     600,
#                                     4200,
#                                 ),
#                             ],
#                             type='RandomChoiceResize'),
#                         dict(
#                             allow_negative_crop=True,
#                             crop_size=(
#                                 384,
#                                 600,
#                             ),
#                             crop_type='absolute_range',
#                             type='RandomCrop'),
#                         dict(
#                             keep_ratio=True,
#                             scales=[
#                                 (
#                                     480,
#                                     1333,
#                                 ),
#                                 (
#                                     512,
#                                     1333,
#                                 ),
#                                 (
#                                     544,
#                                     1333,
#                                 ),
#                                 (
#                                     576,
#                                     1333,
#                                 ),
#                                 (
#                                     608,
#                                     1333,
#                                 ),
#                                 (
#                                     640,
#                                     1333,
#                                 ),
#                                 (
#                                     672,
#                                     1333,
#                                 ),
#                                 (
#                                     704,
#                                     1333,
#                                 ),
#                                 (
#                                     736,
#                                     1333,
#                                 ),
#                                 (
#                                     768,
#                                     1333,
#                                 ),
#                                 (
#                                     800,
#                                     1333,
#                                 ),
#                             ],
#                             type='RandomChoiceResize'),
#                     ],
#                 ],
#                 type='RandomChoice'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'flip',
#                     'flip_direction',
#                     'text',
#                     'custom_entities',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         return_classes=True,
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(
#         transforms=[
#             [
#                 dict(
#                     keep_ratio=True,
#                     scales=[
#                         (
#                             480,
#                             1333,
#                         ),
#                         (
#                             512,
#                             1333,
#                         ),
#                         (
#                             544,
#                             1333,
#                         ),
#                         (
#                             576,
#                             1333,
#                         ),
#                         (
#                             608,
#                             1333,
#                         ),
#                         (
#                             640,
#                             1333,
#                         ),
#                         (
#                             672,
#                             1333,
#                         ),
#                         (
#                             704,
#                             1333,
#                         ),
#                         (
#                             736,
#                             1333,
#                         ),
#                         (
#                             768,
#                             1333,
#                         ),
#                         (
#                             800,
#                             1333,
#                         ),
#                     ],
#                     type='RandomChoiceResize'),
#             ],
#             [
#                 dict(
#                     keep_ratio=True,
#                     scales=[
#                         (
#                             400,
#                             4200,
#                         ),
#                         (
#                             500,
#                             4200,
#                         ),
#                         (
#                             600,
#                             4200,
#                         ),
#                     ],
#                     type='RandomChoiceResize'),
#                 dict(
#                     allow_negative_crop=True,
#                     crop_size=(
#                         384,
#                         600,
#                     ),
#                     crop_type='absolute_range',
#                     type='RandomCrop'),
#                 dict(
#                     keep_ratio=True,
#                     scales=[
#                         (
#                             480,
#                             1333,
#                         ),
#                         (
#                             512,
#                             1333,
#                         ),
#                         (
#                             544,
#                             1333,
#                         ),
#                         (
#                             576,
#                             1333,
#                         ),
#                         (
#                             608,
#                             1333,
#                         ),
#                         (
#                             640,
#                             1333,
#                         ),
#                         (
#                             672,
#                             1333,
#                         ),
#                         (
#                             704,
#                             1333,
#                         ),
#                         (
#                             736,
#                             1333,
#                         ),
#                         (
#                             768,
#                             1333,
#                         ),
#                         (
#                             800,
#                             1333,
#                         ),
#                     ],
#                     type='RandomChoiceResize'),
#             ],
#         ],
#         type='RandomChoice'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'flip',
#             'flip_direction',
#             'text',
#             'custom_entities',
#         ),
#         type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='test/'),
#         data_root='data/',
#         metainfo=dict(
#             classes=(
#                 'Defect1',
#                 'Defect2',
#                 'Defect3',
#                 'Defect4',
#                 'Defect5',
#             ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     0,
#                     0,
#                     142,
#                 ),
#                 (
#                     0,
#                     255,
#                     0,
#                 ),
#                 (
#                     255,
#                     165,
#                     0,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 800,
#                 1333,
#             ), type='FixScaleResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'text',
#                     'custom_entities',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         return_classes=True,
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='data/test/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = 'defect_work_dir'
#
# 07/21 13:55:32 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 07/21 13:55:32 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr=5e-06
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:weight_decay=0.0001
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr_mult=0.1
# 07/21 13:55:33 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr=5e-06
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:weight_decay=0.0001
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr_mult=0.1
# 07/21 13:55:34 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr=5e-06
# ...
# 07/21 14:47:34 - mmengine - INFO - Epoch(train) [10][35/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:01:32  time: 1.8738  data_time: 0.0143  memory: 4220  grad_norm: 332.5703  loss: 12.4761  loss_cls: 0.3215  loss_bbox: 0.3452  loss_iou: 0.4007  d0.loss_cls: 0.3678  d0.loss_bbox: 0.3500  d0.loss_iou: 0.4063  d1.loss_cls: 0.3666  d1.loss_bbox: 0.3326  d1.loss_iou: 0.3872  d2.loss_cls: 0.3460  d2.loss_bbox: 0.3422  d2.loss_iou: 0.4021  d3.loss_cls: 0.3232  d3.loss_bbox: 0.3466  d3.loss_iou: 0.4054  d4.loss_cls: 0.3210  d4.loss_bbox: 0.3469  d4.loss_iou: 0.4028  enc_loss_cls: 0.4127  enc_loss_bbox: 0.3480  enc_loss_iou: 0.3996  dn_loss_cls: 0.1678  dn_loss_bbox: 0.2713  dn_loss_iou: 0.3154  d0.dn_loss_cls: 0.2150  d0.dn_loss_bbox: 0.3755  d0.dn_loss_iou: 0.4217  d1.dn_loss_cls: 0.1708  d1.dn_loss_bbox: 0.2784  d1.dn_loss_iou: 0.3236  d2.dn_loss_cls: 0.1662  d2.dn_loss_bbox: 0.2717  d2.dn_loss_iou: 0.3157  d3.dn_loss_cls: 0.1650  d3.dn_loss_bbox: 0.2715  d3.dn_loss_iou: 0.3155  d4.dn_loss_cls: 0.1696  d4.dn_loss_bbox: 0.2716  d4.dn_loss_iou: 0.3155
# 07/21 14:47:43 - mmengine - INFO - Epoch(train) [10][40/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:01:23  time: 1.8867  data_time: 0.0143  memory: 4073  grad_norm: 335.7999  loss: 12.5490  loss_cls: 0.3129  loss_bbox: 0.3592  loss_iou: 0.4178  d0.loss_cls: 0.3690  d0.loss_bbox: 0.3541  d0.loss_iou: 0.4166  d1.loss_cls: 0.3714  d1.loss_bbox: 0.3310  d1.loss_iou: 0.3887  d2.loss_cls: 0.3403  d2.loss_bbox: 0.3473  d2.loss_iou: 0.4106  d3.loss_cls: 0.3154  d3.loss_bbox: 0.3542  d3.loss_iou: 0.4178  d4.loss_cls: 0.3122  d4.loss_bbox: 0.3603  d4.loss_iou: 0.4194  enc_loss_cls: 0.4196  enc_loss_bbox: 0.3470  enc_loss_iou: 0.4018  dn_loss_cls: 0.1591  dn_loss_bbox: 0.2716  dn_loss_iou: 0.3172  d0.dn_loss_cls: 0.2098  d0.dn_loss_bbox: 0.3775  d0.dn_loss_iou: 0.4280  d1.dn_loss_cls: 0.1679  d1.dn_loss_bbox: 0.2795  d1.dn_loss_iou: 0.3263  d2.dn_loss_cls: 0.1603  d2.dn_loss_bbox: 0.2722  d2.dn_loss_iou: 0.3178  d3.dn_loss_cls: 0.1564  d3.dn_loss_bbox: 0.2716  d3.dn_loss_iou: 0.3170  d4.dn_loss_cls: 0.1610  d4.dn_loss_bbox: 0.2720  d4.dn_loss_iou: 0.3173
# 07/21 14:47:52 - mmengine - INFO - Epoch(train) [10][45/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:01:13  time: 1.8773  data_time: 0.0143  memory: 4157  grad_norm: 338.9051  loss: 12.8269  loss_cls: 0.3014  loss_bbox: 0.3769  loss_iou: 0.4361  d0.loss_cls: 0.3690  d0.loss_bbox: 0.3682  d0.loss_iou: 0.4337  d1.loss_cls: 0.3760  d1.loss_bbox: 0.3455  d1.loss_iou: 0.4064  d2.loss_cls: 0.3387  d2.loss_bbox: 0.3635  d2.loss_iou: 0.4259  d3.loss_cls: 0.3117  d3.loss_bbox: 0.3692  d3.loss_iou: 0.4324  d4.loss_cls: 0.3044  d4.loss_bbox: 0.3767  d4.loss_iou: 0.4357  enc_loss_cls: 0.4177  enc_loss_bbox: 0.3595  enc_loss_iou: 0.4178  dn_loss_cls: 0.1532  dn_loss_bbox: 0.2789  dn_loss_iou: 0.3269  d0.dn_loss_cls: 0.2051  d0.dn_loss_bbox: 0.3878  d0.dn_loss_iou: 0.4410  d1.dn_loss_cls: 0.1633  d1.dn_loss_bbox: 0.2866  d1.dn_loss_iou: 0.3359  d2.dn_loss_cls: 0.1554  d2.dn_loss_bbox: 0.2798  d2.dn_loss_iou: 0.3276  d3.dn_loss_cls: 0.1517  d3.dn_loss_bbox: 0.2789  d3.dn_loss_iou: 0.3267  d4.dn_loss_cls: 0.1554  d4.dn_loss_bbox: 0.2792  d4.dn_loss_iou: 0.3270
# 07/21 14:48:01 - mmengine - INFO - Epoch(train) [10][50/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:01:04  time: 1.9046  data_time: 0.0149  memory: 4155  grad_norm: 352.3743  loss: 12.5203  loss_cls: 0.2831  loss_bbox: 0.3663  loss_iou: 0.4407  d0.loss_cls: 0.3511  d0.loss_bbox: 0.3583  d0.loss_iou: 0.4363  d1.loss_cls: 0.3583  d1.loss_bbox: 0.3375  d1.loss_iou: 0.4120  d2.loss_cls: 0.3208  d2.loss_bbox: 0.3557  d2.loss_iou: 0.4330  d3.loss_cls: 0.2956  d3.loss_bbox: 0.3599  d3.loss_iou: 0.4389  d4.loss_cls: 0.2862  d4.loss_bbox: 0.3661  d4.loss_iou: 0.4403  enc_loss_cls: 0.4003  enc_loss_bbox: 0.3560  enc_loss_iou: 0.4233  dn_loss_cls: 0.1458  dn_loss_bbox: 0.2649  dn_loss_iou: 0.3229  d0.dn_loss_cls: 0.1949  d0.dn_loss_bbox: 0.3705  d0.dn_loss_iou: 0.4372  d1.dn_loss_cls: 0.1542  d1.dn_loss_bbox: 0.2726  d1.dn_loss_iou: 0.3316  d2.dn_loss_cls: 0.1473  d2.dn_loss_bbox: 0.2662  d2.dn_loss_iou: 0.3239  d3.dn_loss_cls: 0.1444  d3.dn_loss_bbox: 0.2649  d3.dn_loss_iou: 0.3228  d4.dn_loss_cls: 0.1483  d4.dn_loss_bbox: 0.2652  d4.dn_loss_iou: 0.3230
# 07/21 14:48:10 - mmengine - INFO - Epoch(train) [10][55/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:00:55  time: 1.8638  data_time: 0.0136  memory: 4073  grad_norm: 419.2291  loss: 12.8799  loss_cls: 0.2861  loss_bbox: 0.3838  loss_iou: 0.4561  d0.loss_cls: 0.3639  d0.loss_bbox: 0.3613  d0.loss_iou: 0.4396  d1.loss_cls: 0.3698  d1.loss_bbox: 0.3462  d1.loss_iou: 0.4210  d2.loss_cls: 0.3264  d2.loss_bbox: 0.3693  d2.loss_iou: 0.4426  d3.loss_cls: 0.2992  d3.loss_bbox: 0.3741  d3.loss_iou: 0.4491  d4.loss_cls: 0.2860  d4.loss_bbox: 0.3832  d4.loss_iou: 0.4555  enc_loss_cls: 0.4108  enc_loss_bbox: 0.3733  enc_loss_iou: 0.4363  dn_loss_cls: 0.1630  dn_loss_bbox: 0.2698  dn_loss_iou: 0.3275  d0.dn_loss_cls: 0.2081  d0.dn_loss_bbox: 0.3779  d0.dn_loss_iou: 0.4422  d1.dn_loss_cls: 0.1747  d1.dn_loss_bbox: 0.2772  d1.dn_loss_iou: 0.3353  d2.dn_loss_cls: 0.1616  d2.dn_loss_bbox: 0.2705  d2.dn_loss_iou: 0.3280  d3.dn_loss_cls: 0.1549  d3.dn_loss_bbox: 0.2697  d3.dn_loss_iou: 0.3276  d4.dn_loss_cls: 0.1610  d4.dn_loss_bbox: 0.2699  d4.dn_loss_iou: 0.3275
# 07/21 14:48:19 - mmengine - INFO - Epoch(train) [10][60/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:00:46  time: 1.8467  data_time: 0.0138  memory: 4178  grad_norm: 412.1922  loss: 12.8185  loss_cls: 0.2599  loss_bbox: 0.3924  loss_iou: 0.4714  d0.loss_cls: 0.3490  d0.loss_bbox: 0.3600  d0.loss_iou: 0.4450  d1.loss_cls: 0.3409  d1.loss_bbox: 0.3559  d1.loss_iou: 0.4378  d2.loss_cls: 0.2954  d2.loss_bbox: 0.3747  d2.loss_iou: 0.4560  d3.loss_cls: 0.2753  d3.loss_bbox: 0.3824  d3.loss_iou: 0.4634  d4.loss_cls: 0.2603  d4.loss_bbox: 0.3917  d4.loss_iou: 0.4707  enc_loss_cls: 0.3952  enc_loss_bbox: 0.3653  enc_loss_iou: 0.4430  dn_loss_cls: 0.1529  dn_loss_bbox: 0.2718  dn_loss_iou: 0.3370  d0.dn_loss_cls: 0.1952  d0.dn_loss_bbox: 0.3758  d0.dn_loss_iou: 0.4490  d1.dn_loss_cls: 0.1605  d1.dn_loss_bbox: 0.2783  d1.dn_loss_iou: 0.3446  d2.dn_loss_cls: 0.1478  d2.dn_loss_bbox: 0.2723  d2.dn_loss_iou: 0.3373  d3.dn_loss_cls: 0.1418  d3.dn_loss_bbox: 0.2714  d3.dn_loss_iou: 0.3369  d4.dn_loss_cls: 0.1515  d4.dn_loss_bbox: 0.2719  d4.dn_loss_iou: 0.3371
# 07/21 14:48:27 - mmengine - INFO - Epoch(train) [10][65/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:00:36  time: 1.8098  data_time: 0.0137  memory: 4207  grad_norm: 419.4743  loss: 13.0898  loss_cls: 0.2578  loss_bbox: 0.4043  loss_iou: 0.4916  d0.loss_cls: 0.3557  d0.loss_bbox: 0.3657  d0.loss_iou: 0.4588  d1.loss_cls: 0.3438  d1.loss_bbox: 0.3599  d1.loss_iou: 0.4517  d2.loss_cls: 0.2937  d2.loss_bbox: 0.3854  d2.loss_iou: 0.4759  d3.loss_cls: 0.2731  d3.loss_bbox: 0.3917  d3.loss_iou: 0.4811  d4.loss_cls: 0.2630  d4.loss_bbox: 0.4028  d4.loss_iou: 0.4901  enc_loss_cls: 0.3951  enc_loss_bbox: 0.3794  enc_loss_iou: 0.4668  dn_loss_cls: 0.1572  dn_loss_bbox: 0.2727  dn_loss_iou: 0.3430  d0.dn_loss_cls: 0.2015  d0.dn_loss_bbox: 0.3761  d0.dn_loss_iou: 0.4575  d1.dn_loss_cls: 0.1651  d1.dn_loss_bbox: 0.2788  d1.dn_loss_iou: 0.3506  d2.dn_loss_cls: 0.1518  d2.dn_loss_bbox: 0.2730  d2.dn_loss_iou: 0.3433  d3.dn_loss_cls: 0.1453  d3.dn_loss_bbox: 0.2722  d3.dn_loss_iou: 0.3428  d4.dn_loss_cls: 0.1557  d4.dn_loss_bbox: 0.2728  d4.dn_loss_iou: 0.3430
# 07/21 14:48:38 - mmengine - INFO - Epoch(train) [10][70/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:00:27  time: 1.8485  data_time: 0.0139  memory: 4485  grad_norm: 440.0000  loss: 13.1681  loss_cls: 0.2600  loss_bbox: 0.4126  loss_iou: 0.4835  d0.loss_cls: 0.3689  d0.loss_bbox: 0.3618  d0.loss_iou: 0.4379  d1.loss_cls: 0.3537  d1.loss_bbox: 0.3580  d1.loss_iou: 0.4310  d2.loss_cls: 0.2909  d2.loss_bbox: 0.3939  d2.loss_iou: 0.4638  d3.loss_cls: 0.2881  d3.loss_bbox: 0.3897  d3.loss_iou: 0.4642  d4.loss_cls: 0.2642  d4.loss_bbox: 0.4105  d4.loss_iou: 0.4815  enc_loss_cls: 0.4061  enc_loss_bbox: 0.3745  enc_loss_iou: 0.4468  dn_loss_cls: 0.1764  dn_loss_bbox: 0.2809  dn_loss_iou: 0.3381  d0.dn_loss_cls: 0.2168  d0.dn_loss_bbox: 0.3781  d0.dn_loss_iou: 0.4443  d1.dn_loss_cls: 0.1808  d1.dn_loss_bbox: 0.2858  d1.dn_loss_iou: 0.3445  d2.dn_loss_cls: 0.1778  d2.dn_loss_bbox: 0.2808  d2.dn_loss_iou: 0.3380  d3.dn_loss_cls: 0.1697  d3.dn_loss_bbox: 0.2803  d3.dn_loss_iou: 0.3379  d4.dn_loss_cls: 0.1773  d4.dn_loss_bbox: 0.2809  d4.dn_loss_iou: 0.3381
# 07/21 14:48:48 - mmengine - INFO - Epoch(train) [10][75/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:00:18  time: 1.8403  data_time: 0.0135  memory: 4185  grad_norm: 438.8232  loss: 13.0239  loss_cls: 0.2573  loss_bbox: 0.4145  loss_iou: 0.4719  d0.loss_cls: 0.3433  d0.loss_bbox: 0.3731  d0.loss_iou: 0.4393  d1.loss_cls: 0.3320  d1.loss_bbox: 0.3671  d1.loss_iou: 0.4287  d2.loss_cls: 0.2757  d2.loss_bbox: 0.3995  d2.loss_iou: 0.4566  d3.loss_cls: 0.2711  d3.loss_bbox: 0.3943  d3.loss_iou: 0.4598  d4.loss_cls: 0.2587  d4.loss_bbox: 0.4118  d4.loss_iou: 0.4690  enc_loss_cls: 0.3874  enc_loss_bbox: 0.3754  enc_loss_iou: 0.4406  dn_loss_cls: 0.1600  dn_loss_bbox: 0.2906  dn_loss_iou: 0.3385  d0.dn_loss_cls: 0.2089  d0.dn_loss_bbox: 0.3816  d0.dn_loss_iou: 0.4366  d1.dn_loss_cls: 0.1741  d1.dn_loss_bbox: 0.2950  d1.dn_loss_iou: 0.3444  d2.dn_loss_cls: 0.1668  d2.dn_loss_bbox: 0.2903  d2.dn_loss_iou: 0.3382  d3.dn_loss_cls: 0.1554  d3.dn_loss_bbox: 0.2900  d3.dn_loss_iou: 0.3383  d4.dn_loss_cls: 0.1591  d4.dn_loss_bbox: 0.2906  d4.dn_loss_iou: 0.3385
# 07/21 14:48:58 - mmengine - INFO - Epoch(train) [10][80/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:00:09  time: 1.8425  data_time: 0.0141  memory: 4157  grad_norm: 475.0396  loss: 13.0495  loss_cls: 0.2528  loss_bbox: 0.4250  loss_iou: 0.4820  d0.loss_cls: 0.3429  d0.loss_bbox: 0.3754  d0.loss_iou: 0.4409  d1.loss_cls: 0.3327  d1.loss_bbox: 0.3707  d1.loss_iou: 0.4324  d2.loss_cls: 0.2762  d2.loss_bbox: 0.4037  d2.loss_iou: 0.4613  d3.loss_cls: 0.2729  d3.loss_bbox: 0.3990  d3.loss_iou: 0.4632  d4.loss_cls: 0.2602  d4.loss_bbox: 0.4142  d4.loss_iou: 0.4729  enc_loss_cls: 0.3852  enc_loss_bbox: 0.3838  enc_loss_iou: 0.4468  dn_loss_cls: 0.1551  dn_loss_bbox: 0.2883  dn_loss_iou: 0.3361  d0.dn_loss_cls: 0.2042  d0.dn_loss_bbox: 0.3842  d0.dn_loss_iou: 0.4372  d1.dn_loss_cls: 0.1722  d1.dn_loss_bbox: 0.2935  d1.dn_loss_iou: 0.3415  d2.dn_loss_cls: 0.1639  d2.dn_loss_bbox: 0.2883  d2.dn_loss_iou: 0.3358  d3.dn_loss_cls: 0.1510  d3.dn_loss_bbox: 0.2884  d3.dn_loss_iou: 0.3361  d4.dn_loss_cls: 0.1550  d4.dn_loss_bbox: 0.2883  d4.dn_loss_iou: 0.3360
# 07/21 14:49:07 - mmengine - INFO - Exp name: grounding_dino_swin-t_finetune_8xb2_20e_cat_20240721_135524
# 07/21 14:49:07 - mmengine - INFO - Epoch(train) [10][85/85]  base_lr: 5.0000e-05 lr: 5.0000e-05  eta: 0:00:00  time: 1.8574  data_time: 0.0139  memory: 4202  grad_norm: 473.6795  loss: 13.2736  loss_cls: 0.2771  loss_bbox: 0.4201  loss_iou: 0.4714  d0.loss_cls: 0.3630  d0.loss_bbox: 0.3781  d0.loss_iou: 0.4399  d1.loss_cls: 0.3546  d1.loss_bbox: 0.3726  d1.loss_iou: 0.4322  d2.loss_cls: 0.2946  d2.loss_bbox: 0.4074  d2.loss_iou: 0.4631  d3.loss_cls: 0.2948  d3.loss_bbox: 0.3984  d3.loss_iou: 0.4571  d4.loss_cls: 0.2803  d4.loss_bbox: 0.4118  d4.loss_iou: 0.4641  enc_loss_cls: 0.3843  enc_loss_bbox: 0.3995  enc_loss_iou: 0.4603  dn_loss_cls: 0.1600  dn_loss_bbox: 0.2963  dn_loss_iou: 0.3398  d0.dn_loss_cls: 0.2061  d0.dn_loss_bbox: 0.3955  d0.dn_loss_iou: 0.4440  d1.dn_loss_cls: 0.1712  d1.dn_loss_bbox: 0.3033  d1.dn_loss_iou: 0.3470  d2.dn_loss_cls: 0.1633  d2.dn_loss_bbox: 0.2968  d2.dn_loss_iou: 0.3399  d3.dn_loss_cls: 0.1545  d3.dn_loss_bbox: 0.2964  d3.dn_loss_iou: 0.3398  d4.dn_loss_cls: 0.1589  d4.dn_loss_bbox: 0.2962  d4.dn_loss_iou: 0.3397
# 07/21 14:49:07 - mmengine - INFO - Saving checkpoint at 10 epochs
# /usr/local/lib/python3.10/dist-packages/mmcv/cnn/bricks/transformer.py:524: UserWarning: position encoding of key ismissing in MultiheadAttention.
#   warnings.warn(f'position encoding of key is'
# 07/21 14:50:35 - mmengine - INFO - Epoch(val) [10][ 5/69]    eta: 0:00:17  time: 0.2704  data_time: 0.0042  memory: 2298
# 07/21 14:50:37 - mmengine - INFO - Epoch(val) [10][10/69]    eta: 0:00:15  time: 0.2702  data_time: 0.0042  memory: 2298
# 07/21 14:50:38 - mmengine - INFO - Epoch(val) [10][15/69]    eta: 0:00:14  time: 0.2696  data_time: 0.0040  memory: 2298
# 07/21 14:50:39 - mmengine - INFO - Epoch(val) [10][20/69]    eta: 0:00:12  time: 0.2691  data_time: 0.0040  memory: 2298
# 07/21 14:50:41 - mmengine - INFO - Epoch(val) [10][25/69]    eta: 0:00:11  time: 0.2707  data_time: 0.0043  memory: 2298
# 07/21 14:50:42 - mmengine - INFO - Epoch(val) [10][30/69]    eta: 0:00:10  time: 0.2729  data_time: 0.0048  memory: 2298
# 07/21 14:50:44 - mmengine - INFO - Epoch(val) [10][35/69]    eta: 0:00:09  time: 0.2746  data_time: 0.0051  memory: 2298
# 07/21 14:50:45 - mmengine - INFO - Epoch(val) [10][40/69]    eta: 0:00:07  time: 0.2770  data_time: 0.0059  memory: 2298
# 07/21 14:50:46 - mmengine - INFO - Epoch(val) [10][45/69]    eta: 0:00:06  time: 0.2777  data_time: 0.0062  memory: 2298
# 07/21 14:50:48 - mmengine - INFO - Epoch(val) [10][50/69]    eta: 0:00:05  time: 0.2754  data_time: 0.0061  memory: 2298
# 07/21 14:50:49 - mmengine - INFO - Epoch(val) [10][55/69]    eta: 0:00:03  time: 0.2739  data_time: 0.0057  memory: 2298
# 07/21 14:50:50 - mmengine - INFO - Epoch(val) [10][60/69]    eta: 0:00:02  time: 0.2744  data_time: 0.0057  memory: 2298
# 07/21 14:50:52 - mmengine - INFO - Epoch(val) [10][65/69]    eta: 0:00:01  time: 0.2753  data_time: 0.0057  memory: 2298
# 07/21 14:50:53 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.40s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.380
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.689
# 07/21 14:50:54 - mmengine - INFO - bbox_mAP_copypaste: 0.403 0.826 0.380 -1.000 0.212 0.447
# 07/21 14:50:54 - mmengine - INFO - Epoch(val) [10][69/69]    coco/bbox_mAP: 0.4030  coco/bbox_mAP_50: 0.8260  coco/bbox_mAP_75: 0.3800  coco/bbox_mAP_s: -1.0000  coco/bbox_mAP_m: 0.2120  coco/bbox_mAP_l: 0.4470  data_time: 0.0053  time: 0.2728
# 07/21 14:50:54 - mmengine - INFO - The previous best checkpoint /content/mmdetection/defect_work_dir/best_coco_bbox_mAP_epoch_9.pth is removed
# 07/21 14:51:00 - mmengine - INFO - The best checkpoint with 0.4030 coco/bbox_mAP at 10 epoch is saved to best_coco_bbox_mAP_epoch_10.pth.

# %%
# !nvidia-smi

# %%
# !nvcc --version

# %%
# !pip install torch==2.1.0 torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/nightly/cu121

# %%
# !pip install fairscale

# %%
import nltk
nltk.download('punkt')

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

# %%
# !python tools/test.py configs/grounding_dino/grounding_dino_swin-t_finetune_8xb2_20e_cat.py defect_work_dir/best_coco_bbox_mAP_epoch_10.pth
# Out:
# 07/21 14:57:06 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1919970001
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu121
#     OpenCV: 4.8.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1919970001
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/21 14:57:08 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# class_name = (
#     'Defect1',
#     'Defect2',
#     'Defect3',
#     'Defect4',
#     'Defect5',
# )
# data_root = 'data/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1, max_keep_ckpts=1, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=5, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# lang_model_name = 'bert-base-uncased'
# launcher = 'none'
# load_from = 'defect_work_dir/best_coco_bbox_mAP_epoch_10.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epoch = 10
# max_epochs = 12
# metainfo = dict(
#     classes=(
#         'Defect1',
#         'Defect2',
#         'Defect3',
#         'Defect4',
#         'Defect5',
#     ),
#     palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#         (
#             119,
#             11,
#             32,
#         ),
#         (
#             0,
#             0,
#             142,
#         ),
#         (
#             0,
#             255,
#             0,
#         ),
#         (
#             255,
#             165,
#             0,
#         ),
#     ])
# model = dict(
#     as_two_stage=True,
#     backbone=dict(
#         attn_drop_rate=0.0,
#         convert_weights=False,
#         depths=[
#             2,
#             2,
#             6,
#             2,
#         ],
#         drop_path_rate=0.2,
#         drop_rate=0.0,
#         embed_dims=96,
#         mlp_ratio=4,
#         num_heads=[
#             3,
#             6,
#             12,
#             24,
#         ],
#         out_indices=(
#             1,
#             2,
#             3,
#         ),
#         patch_norm=True,
#         qk_scale=None,
#         qkv_bias=True,
#         type='SwinTransformer',
#         window_size=7,
#         with_cp=True),
#     bbox_head=dict(
#         contrastive_cfg=dict(bias=False, log_scale=0.0, max_text_len=256),
#         loss_bbox=dict(loss_weight=5.0, type='L1Loss'),
#         loss_cls=dict(
#             alpha=0.25,
#             gamma=2.0,
#             loss_weight=1.0,
#             type='FocalLoss',
#             use_sigmoid=True),
#         loss_iou=dict(loss_weight=2.0, type='GIoULoss'),
#         num_classes=5,
#         sync_cls_avg_factor=True,
#         type='GroundingDINOHead'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_mask=False,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     decoder=dict(
#         layer_cfg=dict(
#             cross_attn_cfg=dict(dropout=0.0, embed_dims=256, num_heads=8),
#             cross_attn_text_cfg=dict(dropout=0.0, embed_dims=256, num_heads=8),
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=2048, ffn_drop=0.0),
#             self_attn_cfg=dict(dropout=0.0, embed_dims=256, num_heads=8)),
#         num_layers=6,
#         post_norm_cfg=None,
#         return_intermediate=True),
#     dn_cfg=dict(
#         box_noise_scale=1.0,
#         group_cfg=dict(dynamic=True, num_dn_queries=100, num_groups=None),
#         label_noise_scale=0.5),
#     encoder=dict(
#         fusion_layer_cfg=dict(
#             embed_dim=1024,
#             init_values=0.0001,
#             l_dim=256,
#             num_heads=4,
#             v_dim=256),
#         layer_cfg=dict(
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=2048, ffn_drop=0.0),
#             self_attn_cfg=dict(dropout=0.0, embed_dims=256, num_levels=4)),
#         num_cp=6,
#         num_layers=6,
#         text_layer_cfg=dict(
#             ffn_cfg=dict(
#                 embed_dims=256, feedforward_channels=1024, ffn_drop=0.0),
#             self_attn_cfg=dict(dropout=0.0, embed_dims=256, num_heads=4))),
#     language_model=dict(
#         add_pooling_layer=False,
#         name='bert-base-uncased',
#         pad_to_max=False,
#         special_tokens_list=[
#             '[CLS]',
#             '[SEP]',
#             '.',
#             '?',
#         ],
#         type='BertModel',
#         use_sub_sentence_represent=True),
#     neck=dict(
#         act_cfg=None,
#         bias=True,
#         in_channels=[
#             192,
#             384,
#             768,
#         ],
#         kernel_size=1,
#         norm_cfg=dict(num_groups=32, type='GN'),
#         num_outs=4,
#         out_channels=256,
#         type='ChannelMapper'),
#     num_queries=900,
#     positional_encoding=dict(
#         normalize=True, num_feats=128, offset=0.0, temperature=20),
#     test_cfg=dict(max_per_img=300),
#     train_cfg=dict(
#         assigner=dict(
#             match_costs=[
#                 dict(type='BinaryFocalLossCost', weight=2.0),
#                 dict(box_format='xywh', type='BBoxL1Cost', weight=5.0),
#                 dict(iou_mode='giou', type='IoUCost', weight=2.0),
#             ],
#             type='HungarianAssigner')),
#     type='GroundingDINO',
#     with_box_refine=True)
# num_classes = 5
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=0.1, norm_type=2),
#     optimizer=dict(lr=5e-05, type='AdamW', weight_decay=0.0001),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             absolute_pos_embed=dict(decay_mult=0.0),
#             backbone=dict(lr_mult=0.1),
#             language_model=dict(lr_mult=0))),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(begin=0, by_epoch=False, end=30, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=10,
#         gamma=0.1,
#         milestones=[
#             15,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='test/'),
#         data_root='data/',
#         metainfo=dict(
#             classes=(
#                 'Defect1',
#                 'Defect2',
#                 'Defect3',
#                 'Defect4',
#                 'Defect5',
#             ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     0,
#                     0,
#                     142,
#                 ),
#                 (
#                     0,
#                     255,
#                     0,
#                 ),
#                 (
#                     255,
#                     165,
#                     0,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 800,
#                 1333,
#             ), type='FixScaleResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'text',
#                     'custom_entities',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         return_classes=True,
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/test/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         800,
#         1333,
#     ), type='FixScaleResize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'text',
#             'custom_entities',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=10, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='data/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'Defect1',
#                 'Defect2',
#                 'Defect3',
#                 'Defect4',
#                 'Defect5',
#             ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     0,
#                     0,
#                     142,
#                 ),
#                 (
#                     0,
#                     255,
#                     0,
#                 ),
#                 (
#                     255,
#                     165,
#                     0,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(
#                 transforms=[
#                     [
#                         dict(
#                             keep_ratio=True,
#                             scales=[
#                                 (
#                                     480,
#                                     1333,
#                                 ),
#                                 (
#                                     512,
#                                     1333,
#                                 ),
#                                 (
#                                     544,
#                                     1333,
#                                 ),
#                                 (
#                                     576,
#                                     1333,
#                                 ),
#                                 (
#                                     608,
#                                     1333,
#                                 ),
#                                 (
#                                     640,
#                                     1333,
#                                 ),
#                                 (
#                                     672,
#                                     1333,
#                                 ),
#                                 (
#                                     704,
#                                     1333,
#                                 ),
#                                 (
#                                     736,
#                                     1333,
#                                 ),
#                                 (
#                                     768,
#                                     1333,
#                                 ),
#                                 (
#                                     800,
#                                     1333,
#                                 ),
#                             ],
#                             type='RandomChoiceResize'),
#                     ],
#                     [
#                         dict(
#                             keep_ratio=True,
#                             scales=[
#                                 (
#                                     400,
#                                     4200,
#                                 ),
#                                 (
#                                     500,
#                                     4200,
#                                 ),
#                                 (
#                                     600,
#                                     4200,
#                                 ),
#                             ],
#                             type='RandomChoiceResize'),
#                         dict(
#                             allow_negative_crop=True,
#                             crop_size=(
#                                 384,
#                                 600,
#                             ),
#                             crop_type='absolute_range',
#                             type='RandomCrop'),
#                         dict(
#                             keep_ratio=True,
#                             scales=[
#                                 (
#                                     480,
#                                     1333,
#                                 ),
#                                 (
#                                     512,
#                                     1333,
#                                 ),
#                                 (
#                                     544,
#                                     1333,
#                                 ),
#                                 (
#                                     576,
#                                     1333,
#                                 ),
#                                 (
#                                     608,
#                                     1333,
#                                 ),
#                                 (
#                                     640,
#                                     1333,
#                                 ),
#                                 (
#                                     672,
#                                     1333,
#                                 ),
#                                 (
#                                     704,
#                                     1333,
#                                 ),
#                                 (
#                                     736,
#                                     1333,
#                                 ),
#                                 (
#                                     768,
#                                     1333,
#                                 ),
#                                 (
#                                     800,
#                                     1333,
#                                 ),
#                             ],
#                             type='RandomChoiceResize'),
#                     ],
#                 ],
#                 type='RandomChoice'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'flip',
#                     'flip_direction',
#                     'text',
#                     'custom_entities',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         return_classes=True,
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(
#         transforms=[
#             [
#                 dict(
#                     keep_ratio=True,
#                     scales=[
#                         (
#                             480,
#                             1333,
#                         ),
#                         (
#                             512,
#                             1333,
#                         ),
#                         (
#                             544,
#                             1333,
#                         ),
#                         (
#                             576,
#                             1333,
#                         ),
#                         (
#                             608,
#                             1333,
#                         ),
#                         (
#                             640,
#                             1333,
#                         ),
#                         (
#                             672,
#                             1333,
#                         ),
#                         (
#                             704,
#                             1333,
#                         ),
#                         (
#                             736,
#                             1333,
#                         ),
#                         (
#                             768,
#                             1333,
#                         ),
#                         (
#                             800,
#                             1333,
#                         ),
#                     ],
#                     type='RandomChoiceResize'),
#             ],
#             [
#                 dict(
#                     keep_ratio=True,
#                     scales=[
#                         (
#                             400,
#                             4200,
#                         ),
#                         (
#                             500,
#                             4200,
#                         ),
#                         (
#                             600,
#                             4200,
#                         ),
#                     ],
#                     type='RandomChoiceResize'),
#                 dict(
#                     allow_negative_crop=True,
#                     crop_size=(
#                         384,
#                         600,
#                     ),
#                     crop_type='absolute_range',
#                     type='RandomCrop'),
#                 dict(
#                     keep_ratio=True,
#                     scales=[
#                         (
#                             480,
#                             1333,
#                         ),
#                         (
#                             512,
#                             1333,
#                         ),
#                         (
#                             544,
#                             1333,
#                         ),
#                         (
#                             576,
#                             1333,
#                         ),
#                         (
#                             608,
#                             1333,
#                         ),
#                         (
#                             640,
#                             1333,
#                         ),
#                         (
#                             672,
#                             1333,
#                         ),
#                         (
#                             704,
#                             1333,
#                         ),
#                         (
#                             736,
#                             1333,
#                         ),
#                         (
#                             768,
#                             1333,
#                         ),
#                         (
#                             800,
#                             1333,
#                         ),
#                     ],
#                     type='RandomChoiceResize'),
#             ],
#         ],
#         type='RandomChoice'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'flip',
#             'flip_direction',
#             'text',
#             'custom_entities',
#         ),
#         type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='test/'),
#         data_root='data/',
#         metainfo=dict(
#             classes=(
#                 'Defect1',
#                 'Defect2',
#                 'Defect3',
#                 'Defect4',
#                 'Defect5',
#             ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     119,
#                     11,
#                     32,
#                 ),
#                 (
#                     0,
#                     0,
#                     142,
#                 ),
#                 (
#                     0,
#                     255,
#                     0,
#                 ),
#                 (
#                     255,
#                     165,
#                     0,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 800,
#                 1333,
#             ), type='FixScaleResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'text',
#                     'custom_entities',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         return_classes=True,
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='data/test/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/grounding_dino_swin-t_finetune_8xb2_20e_cat'
#
# 07/21 14:57:13 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 07/21 14:57:13 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loads checkpoint by local backend from path: defect_work_dir/best_coco_bbox_mAP_epoch_10.pth
# 07/21 14:57:19 - mmengine - INFO - Load checkpoint from defect_work_dir/best_coco_bbox_mAP_epoch_10.pth
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/mmcv/cnn/bricks/transformer.py:524: UserWarning: position encoding of key ismissing in MultiheadAttention.
#   warnings.warn(f'position encoding of key is'
# 07/21 14:57:22 - mmengine - INFO - Epoch(test) [ 5/69]    eta: 0:00:36  time: 0.5780  data_time: 0.0273  memory: 964
# 07/21 14:57:23 - mmengine - INFO - Epoch(test) [10/69]    eta: 0:00:25  time: 0.4244  data_time: 0.0172  memory: 964
# 07/21 14:57:25 - mmengine - INFO - Epoch(test) [15/69]    eta: 0:00:20  time: 0.3713  data_time: 0.0140  memory: 964
# 07/21 14:57:26 - mmengine - INFO - Epoch(test) [20/69]    eta: 0:00:16  time: 0.3434  data_time: 0.0120  memory: 964
# 07/21 14:57:27 - mmengine - INFO - Epoch(test) [25/69]    eta: 0:00:14  time: 0.3234  data_time: 0.0103  memory: 964
# 07/21 14:57:28 - mmengine - INFO - Epoch(test) [30/69]    eta: 0:00:12  time: 0.3100  data_time: 0.0091  memory: 964
# 07/21 14:57:29 - mmengine - INFO - Epoch(test) [35/69]    eta: 0:00:10  time: 0.3004  data_time: 0.0083  memory: 964
# 07/21 14:57:31 - mmengine - INFO - Epoch(test) [40/69]    eta: 0:00:08  time: 0.2933  data_time: 0.0076  memory: 964
# 07/21 14:57:32 - mmengine - INFO - Epoch(test) [45/69]    eta: 0:00:06  time: 0.2875  data_time: 0.0072  memory: 964
# 07/21 14:57:33 - mmengine - INFO - Epoch(test) [50/69]    eta: 0:00:05  time: 0.2829  data_time: 0.0068  memory: 964
# 07/21 14:57:34 - mmengine - INFO - Epoch(test) [55/69]    eta: 0:00:03  time: 0.2494  data_time: 0.0044  memory: 964
# 07/21 14:57:36 - mmengine - INFO - Epoch(test) [60/69]    eta: 0:00:02  time: 0.2469  data_time: 0.0040  memory: 964
# 07/21 14:57:37 - mmengine - INFO - Epoch(test) [65/69]    eta: 0:00:01  time: 0.2468  data_time: 0.0040  memory: 964
# 07/21 14:57:39 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.74s).
# Accumulating evaluation results...
# DONE (t=0.56s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.380
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.689
# 07/21 14:57:40 - mmengine - INFO - bbox_mAP_copypaste: 0.403 0.826 0.380 -1.000 0.212 0.447
# 07/21 14:57:40 - mmengine - INFO - Epoch(test) [69/69]    coco/bbox_mAP: 0.4030  coco/bbox_mAP_50: 0.8260  coco/bbox_mAP_75: 0.3800  coco/bbox_mAP_s: -1.0000  coco/bbox_mAP_m: 0.2120  coco/bbox_mAP_l: 0.4470  data_time: 0.0061  time: 0.2748
